# %%
# The purpose of this program is to use the random module in python 
# to roll a die for our icebreaker today. 
# Korren is going to attempt to do this live, be prepared for typos.

# import the random library
import random

# declare our variables to determine the smallest and larges numbers
min = 1
max = 6

# declare var to keep track of if we need to roll again
# set it to yes to start our program
roll_again = "yes"

# create a loop to start asking the questions
while roll_again == 'yes':
    # print message to indicate die is rolling
    print("Rolling the die...")
    
    # decalre a var for our die value and assign a random number
    die_value = (random.randint(min,max))
    
    # print print the die value
    print("The value of the die is: ", die_value)
    
    # create if statement to tell program what to do for each number
    if die_value == 1:
        print("If you were invisible for a day, what would you do?")
    elif die_value == 2:
        print("If you could choose a super power, what would it be?")
    elif die_value == 3:
        print("What is your favourite food?")
    elif die_value == 4:
        print("Who is your favourite book or movie character?")
    elif die_value == 5:
        print("What is your favourite game to play?")
    else:
        print("what is one thing you are really good at?")
        
    # prompt user to roll again
    roll_again = input("Roll again? yes/no")

	# Ending the program and error handling 
    if roll_again == "no":
        print("you have selected no, program terminating")
    elif roll_again != "yes" or roll_again != "no":
        print("invalid entry, program terminating")

    
print("This message displays at the end")
# Out:
# Rolling the die...
# The value of the die is:  5
# What is your favourite game to play?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  2
# If you could choose a super power, what would it be?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  5
# What is your favourite game to play?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  4
# Who is your favourite book or movie character?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  1
# If you were invisible for a day, what would you do?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  2
# If you could choose a super power, what would it be?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  4
# Who is your favourite book or movie character?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  6
# what is one thing you are really good at?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  2
# If you could choose a super power, what would it be?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  3
# What is your favourite food?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  3
# What is your favourite food?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  4
# Who is your favourite book or movie character?
# Roll again? yes/noyes
# Rolling the die...
# The value of the die is:  5
# What is your favourite game to play?
# Roll again? yes/nono
# This message displays at the end
